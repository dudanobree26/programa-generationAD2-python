# %% [markdown]
# <a href="https://colab.research.google.com/github/dudanobree26/programa-generationAD2-python/blob/main/fundamentos_ciencias_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#para o trabalho com coleta de dados
# 1- entrada manual - usuario informa dados
# 2 - raspagen de dados - web scraping - entra no site e coleta dados
# 3 - importação|automação - sensores, apis....

#vamos usar web scraping para coletar dados de noticia
import requests
import pandas as pd
from datetime import datetime #--> para puxar uma função especifica de uma blibioteca
# FROM bliblioteca IMPORT função

#temos que importar uma blibioteca de web scraping
from bs4 import BeautifulSoup

# %%
# vamos criar a função para coletar os dados do site alvo
def coletar_noticias_g1():
  url_g1 = 'https://g1.globo.com/'

  # vamos usar um agente para que o site não bloqueie a nossa requisição
  headers = {
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
  }

  # agora vamos condicionar nosso uso
  # try - except (if - else)
  # try """"="""" if status.code == 200
  try:
    resposta = requests.get(url_g1, headers=headers)
    # eu quero verificar se deu tudo certo, como se eu tivesse usao status code
    resposta.raise_for_status()

    # vou conectar o web scrap para coletar os dados para nós
    # variavel =
    # chama a biblioteca(método que armazena (response.text), atributo de coleta)
    soup = BeautifulSoup(resposta.text, 'html.parser')

    # de onde vamos pegar as informações
    # comando fild.all('a', class_='feed_post_link') - encontre tudo

    # tags - p - texto paragrafo
    # a ou href - link
    # img - imagem
    # h1, h2, h3 - cabeçalhos
    # video
    posts = soup.find_all('a', class_='feed-post-link')

    lista_noticias = []

    for i in posts:
      titulo = i.get_text()
      link = i.get('href')
      lista_noticias.append({'Titulo':titulo,
                             'Link':link,
                             'Data':datetime.now().strftime('%d/%m/%Y')})
    df_noticias = pd.DataFrame(lista_noticias)

    # dentro do try, para mostrar os dados sempre é legal trazer o return
    return df_noticias
  except Exception as e:
    print('Não consegui ler as noticias')
    return None

# %%
noticias = coletar_noticias_g1()
if noticias is not None:
  display(noticias.head(10))
# Out:
#                                               Titulo  \
# 0  BRB aprova aumento de capital em até R$ 8,8 bi...
# 1  Aumento de capital pressiona caixa do DF, que ...
# 2  Candidata a miss morre ao cair de apartamento;...
# 3  Empresário é morto a tiros durante abordagem d...
# 4  Irã diz que apreendeu 2 navios após Trump este...
# 5  VÍDEO: Irã exibe mísseis balísticos em desfile...
# 6  É #FAKE foto de militar de Israel substituindo...
# 7  Novo Minha Casa, Minha Vida passa a valer hoje...
#
#                                                 Link        Data
# 0  https://g1.globo.com/df/distrito-federal/notic...  22/04/2026
# 1  https://g1.globo.com/economia/blog/ana-flor/po...  22/04/2026
# 2  https://g1.globo.com/rj/rio-de-janeiro/noticia...  22/04/2026
# 3  https://g1.globo.com/rj/rio-de-janeiro/noticia...  22/04/2026
# 4  https://g1.globo.com/mundo/ao-vivo/eua-ataque-...  22/04/2026
# 5  https://g1.globo.com/mundo/noticia/2026/04/22/...  22/04/2026
# 6  https://g1.globo.com/fato-ou-fake/noticia/2026...  22/04/2026
# 7  https://g1.globo.com/economia/noticia/2026/04/...  22/04/2026

# %%
# vamos criar um grafico com o valor médio da gasolina mês a mês em 2025

# para fazer um gráfico precisamos de, pelo menos, dois eixos
x_mes = ['Janeiro', 'Fevereiro', 'Março', 'Junho', 'Agosto', 'Outubro']
# precisamos de um eixo de legenda e um eixo de valor, pelo menos
y_preco = [5.86, 6.50, 6.43, 6.41, 6.20, 6.22]

# a biblioteca que gera graficos é matplotlib ou  potly

# com matplotlib
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4)) # dimensionamento da imagem - OPICIONAL
# para gerar o grafico
# plt.plot(eixo x, eixo y, marker='o', color='COR EM INGLES')
plt.plot(x_mes, y_preco, marker='o', color='blue')
# se quiser titulo
plt.title('gráfico')
#nomear os eixos
plt.xlabel('legendas')
plt.ylabel('valores')
#para mostrar
plt.show()# vamos criar um grafico com o valor médio da gasolina mês a mês em 2025

# para fazer um gráfico precisamos de, pelo menos, dois eixos
x_mes = ['Janeiro', 'Fevereiro', 'Março', 'Junho', 'Agosto', 'Outubro']
# precisamos de um eixo de legenda e um eixo de valor, pelo menos
y_preco = [5.86, 6.50, 6.43, 6.41, 6.20, 6.22]

# a biblioteca que gera graficos é matplotlib ou  potly

# com matplotlib
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4)) # dimensionamento da imagem - OPICIONAL
# para gerar o grafico
# plt.plot(eixo x, eixo y, marker='o', color='COR EM INGLES')
plt.plot(x_mes, y_preco, marker='o', color='blue')
# se quiser titulo
plt.title('gráfico')
#nomear os eixos
plt.xlabel('legendas')
plt.ylabel('valores')
#para mostrar
plt.show()
