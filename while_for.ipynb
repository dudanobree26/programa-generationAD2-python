# %% [markdown]
# <a href="https://colab.research.google.com/github/dudanobree26/programa-generation-AD-2/blob/main/while_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#repetição condicionada - whilw (enquanto)
#contador de tentativas
senha = 1234
contador = 5

while contador != 0:
  validar_senha = int(input('digite a senha '))
  if validar_senha == senha:
    print('senha correta')
    print('acessado')
  else:
    print('senha errada')
    contador -= 1
    print(f'tentativas restantes{contador}')
print('acesso negado')

# %%
contador = 1

#enquanto o contador for <6 ele pergunta pro usuario se ele quer adicionar um valor no contador
while contador < 6:
  pergunta = input('deseja adicionar um valor no contador sim ou não ')
  print(f'valor atual{contador}')

  if pergunta.lower == 'sim':
    contador += 1
    print('contador incrementado')
  else:
    print('nenhum valor adicionado')

print('finalizando o sistema')

# %%
prateleira= ['banana','maça','laranja','uva']

#o comando len(variavel) mosta a quantidade de elementos dentro de algo
print(len(prateleira))

# criar um loop que pergunte ao usuario se ele quer adicionar uma fruta na prateleira
# a prateleira so pode ter 7 itens
# sempre que adicionar um produto deve mostrar seus valores



while len(prateleira) <=7:
  pergunta = input('deseja adicionar mais um item à prateleia ')
  print(f'itens na prateleira {prateleira}')

  if pergunta.lower() == 'sim':
    nova_fruta = input('adicione o item: ')
    prateleira.append(nova_fruta)
    print(f'item adicionado: {prateleira}')

    for i in prateleira: #o *for* deixa de exibir um por um, de forma extensa, e comaça a exibir em forma de lista
      print(i) #o "i" é só um apelido temporário que você dá pra cada item da lista enquanto o loop passa por eles.


      #um outro exemplo
  #for i in prateleira
    #print (f'temos a fruta: {i}')


  else:
    print(f'itens da prateleira {prateleira}')

# %%
#teste o FOR para uma palavra

palavra = 'generation'

for i in palagra:
  print(i)

# %%
#FOR para uma lista

lista = ['aA','bB','cB']

for i in lista:
  print(i)

#FOR para contagem
#o range sempre começa no 0
for i in range(10):
  print(i+1) # i+1 para que inicie no 1, se quisesse que iniciasse no 0, e terminasse no 10, atribuiria ao range o numero 11

# %%
#atividade com o FOR

#criar um programa que pergunte ao usuario o nome de 3 musicas
#adicionar elas em uma tabela e depois
#
lista_musicas = []

while (len(lista_musicas)) <= 2:
  musica = input('adicione TRES de suas musicas favoritas: ')
  lista_musicas.append(musica)


for i in lista_musicas:
    print(i)
